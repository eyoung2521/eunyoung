# %%
 
driver = webdriver.Chrome(executable_path='/Users/eunyoungshin/Desktop/chromedriver')
driver.implicitly_wait(5)

url = 'https://cafe.naver.com/themukja/1515746' # 크롤링 할 카페 주소
joonggonara_id = 10050146 # 크롤링 할 카페id

pages = 1000 # 크롤링할 페이지 수
menu_id = 1731 # 카테고리 아이디 양천구 : 1723
 #2020시작하는 페이지 넘버

result = []

id_ = 'dnb03058'
pw = 'Cr003235bbne+'

# 로그인 전용 화면
driver.get('https://nid.naver.com/nidlogin.login?svctype=262144&url=http://m.naver.com/aside/')
driver.implicitly_wait(2)

# execute_script 함수 사용하여 자바스크립트로 id,pw 넘겨주기
driver.execute_script("document.getElementsByName('id')[0].value=\'"+id_+"\'")
driver.execute_script("document.getElementsByName('pw')[0].value=\'"+pw+"\'")

#/html/body/div[1]/div[2]/div/div[2]/div/form/div/button
# 로그인 버튼 클릭하기
driver.find_element_by_xpath('//*[@id="log.login"]').click()
time.sleep(1)

                          
# 카테고리 열기

#https://cafe.naver.com/joonggonara?iframe_url=/ArticleSearchList.nhn%3Fsearch.clubid=10050146%26search.searchdate=all%26search.searchBy=0%26search.query=%C5%C3%B9%E8%26search.defaultValue=1%26search.menuid=1723

#https://cafe.naver.com/joonggonara?iframe_url=/ArticleList.nhn%3Fsearch.clubid=10050146%26search.page=237%26search.menuid=1723%26search.boardtype=L

#?iframe_url=/ArticleSearchList.nhn%3Fsearch.clubid=10050146%26search.searchdate=all%26search.searchBy=0%26search.query=%C5%C3%B9%E8%26search.defaultValue=1%26search.menuid=1723

#https://cafe.naver.com/joonggonara?iframe_url=/ArticleSearchList.nhn%3Fsearch.clubid=10050146%26search.searchdate=all%26search.searchBy=0%26search.query=%C5%C3%B9%E8%26search.defaultValue=1%26search.menuid=1723%26search.page=20

#driver.get(f'{url}?iframe_url=/ArticleSearchList.nhn%3Fsearch.clubid=10050146%26search.searchdate=all%26search.searchBy=0%26search.query=%C5%C3%B9%E8%26search.defaultValue=1%26search.menuid=1723%26search.page=20)
         

result=[]

        
driver.get("https://cafe.naver.com/joonggonara?iframe_url=/ArticleSearchList.nhn%3Fsearch.clubid=10050146%26search.menuid=1727%26search.searchdate=2020-01-012020-02-26%26search.searchBy=0%26search.sortBy=date%26search.option=3%26userDisplay=50%26search.includeAll=%26search.exclude=%26search.include=%26search.exact=%26search.page=1")
        
time.sleep(2)
        
driver.switch_to.frame("cafe_main")# iframe으로 전환
driver.find_element_by_xpath('//*[@id="main-area"]/div[5]/table/tbody/tr[1]/td[1]/div[2]/div/a').click()

    
for l in range(1,15000):
    
   
        
        try:
            cont_catag = driver.find_element_by_class_name('title_category').text
        except: # 동이 없는 글이면 크롤링 부적절(이 경우 DB에 저장하지 않고 넘어감)
            cont_catag = '없음'
            pass


        # 게시물 작성일
        cont_date = driver.find_element_by_class_name('date').text


        #게시물 제목
        cont_title = driver.find_element_by_class_name('title_text').text
        
        print(cont_catag, cont_title,cont_date)
        
        val = [cont_catag, cont_title, cont_date]
        result.append(val)
        
        time.sleep(0.5)
        driver.find_element_by_link_text('다음글').click()
        
        
        
    
conn.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5e2cf5e1be39> in <module>
# ----> 1 driver = webdriver.Chrome(executable_path='/Users/eunyoungshin/Desktop/chromedriver')
#       2 driver.implicitly_wait(5)
#       3
#       4 url = 'https://cafe.naver.com/themukja/1515746' # 크롤링 할 카페 주소
#       5 joonggonara_id = 10050146 # 크롤링 할 카페id
#
# NameError: name 'webdriver' is not defined

# %%
col_name = ['category','content',"date"]
list_df = pd.DataFrame(result, columns=col_name)

list_df.to_csv('/Users/eunyoungshin/Desktop/강남구10.csv')

# %%
from selenium import webdriver
import time
from bs4 import BeautifulSoup as bs
import re
import pandas as pd

# %%
driver = webdriver.Chrome(executable_path='/Users/eunyoungshin/Desktop/chromedriver')
driver.implicitly_wait(5)

url = 'https://cafe.naver.com/joonggonara' # 크롤링 할 카페 주소
joonggonara_id = 10050146 # 크롤링 할 카페id

pages = 1000 # 크롤링할 페이지 수
menu_id = 1731 # 카테고리 아이디 양천구 : 1723
 #2020시작하는 페이지 넘버

result = []

id_ = 'dnb03058'
pw = 'Cr003235bbne+'

# 로그인 전용 화면
driver.get('https://nid.naver.com/nidlogin.login?svctype=262144&url=http://m.naver.com/aside/')
driver.implicitly_wait(2)

# execute_script 함수 사용하여 자바스크립트로 id,pw 넘겨주기
driver.execute_script("document.getElementsByName('id')[0].value=\'"+id_+"\'")
driver.execute_script("document.getElementsByName('pw')[0].value=\'"+pw+"\'")

#/html/body/div[1]/div[2]/div/div[2]/div/form/div/button
# 로그인 버튼 클릭하기
driver.find_element_by_xpath('//*[@id="log.login"]').click()
time.sleep(1)

                          
# 카테고리 열기

#https://cafe.naver.com/joonggonara?iframe_url=/ArticleSearchList.nhn%3Fsearch.clubid=10050146%26search.searchdate=all%26search.searchBy=0%26search.query=%C5%C3%B9%E8%26search.defaultValue=1%26search.menuid=1723

#https://cafe.naver.com/joonggonara?iframe_url=/ArticleList.nhn%3Fsearch.clubid=10050146%26search.page=237%26search.menuid=1723%26search.boardtype=L

#?iframe_url=/ArticleSearchList.nhn%3Fsearch.clubid=10050146%26search.searchdate=all%26search.searchBy=0%26search.query=%C5%C3%B9%E8%26search.defaultValue=1%26search.menuid=1723

#https://cafe.naver.com/joonggonara?iframe_url=/ArticleSearchList.nhn%3Fsearch.clubid=10050146%26search.searchdate=all%26search.searchBy=0%26search.query=%C5%C3%B9%E8%26search.defaultValue=1%26search.menuid=1723%26search.page=20

#driver.get(f'{url}?iframe_url=/ArticleSearchList.nhn%3Fsearch.clubid=10050146%26search.searchdate=all%26search.searchBy=0%26search.query=%C5%C3%B9%E8%26search.defaultValue=1%26search.menuid=1723%26search.page=20)
         

result=[]

        
driver.get("https://cafe.naver.com/joonggonara?iframe_url=/ArticleSearchList.nhn%3Fsearch.clubid=10050146%26search.menuid=1731%26search.searchdate=2021-08-082020-08-15%26search.searchBy=0%26search.sortBy=date%26search.option=3%26userDisplay=50%26search.query=%B0%C5%B7%A1%26search.includeAll=%26search.exclude=%26search.include=%26search.exact=%26search.page=1")
        
time.sleep(2)
        
driver.switch_to.frame("cafe_main")# iframe으로 전환
    
for l in range(1,100):
    
    for i in range(1,51):
    
        driver.find_element_by_xpath('//*[@id="main-area"]/div[5]/table/tbody/tr['+str(j)+']/td[1]/div[2]/div/a')

        try:
            cont_catag = driver.find_element_by_class_name('head').text
        except: # 동이 없는 글이면 크롤링 부적절(이 경우 DB에 저장하지 않고 넘어감)
            cont_catag = '없음'
            pass

        cont_title = driver.find_element_by_class_name('article').text
        
        driver.find_element_by_xpath('//*[@id="main-area"]/div[5]/table/tbody/tr['+str(j)+']/td[3]')
        
        # 게시물 작성일
        cont_date = driver.find_element_by_class_name('td_date').text

        print(cont_catag, cont_title,cont_date,cont_price)

        val = [cont_catag, cont_title, cont_date]
        result.append(val)
        

    

    if l % 10 == 0:
        c10 = driver.find_element_by_link_text('다음')
        c10.click()
    else:
        a = str(l+1)
        c = driver.find_element_by_link_text(a)
        c.click()
    time.sleep(2)
    
conn.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-2d3e3dbb655a> in <module>
#      54     for i in range(1,51):
#      55
# ---> 56         driver.find_element_by_xpath('//*[@id="main-area"]/div[5]/table/tbody/tr['+str(j)+']/td[1]/div[2]/div/a')
#      57
#      58         try:
#
# NameError: name 'j' is not defined

# %%
driver = webdriver.Chrome(executable_path='/Users/eunyoungshin/Desktop/chromedriver')
driver.implicitly_wait(5)

url = 'https://cafe.naver.com/joonggonara' # 크롤링 할 카페 주소
joonggonara_id = 10050146 # 크롤링 할 카페id

pages = 1000 # 크롤링할 페이지 수
menu_id = 1731 # 카테고리 아이디 양천구 : 1723
 #2020시작하는 페이지 넘버

result = []

id_ = 'dnb03058'
pw = 'Cr003235bbne+'

# 로그인 전용 화면
driver.get('https://nid.naver.com/nidlogin.login?svctype=262144&url=http://m.naver.com/aside/')
driver.implicitly_wait(2)

# execute_script 함수 사용하여 자바스크립트로 id,pw 넘겨주기
driver.execute_script("document.getElementsByName('id')[0].value=\'"+id_+"\'")
driver.execute_script("document.getElementsByName('pw')[0].value=\'"+pw+"\'")

#/html/body/div[1]/div[2]/div/div[2]/div/form/div/button
# 로그인 버튼 클릭하기
driver.find_element_by_xpath('//*[@id="log.login"]').click()
time.sleep(1)

              
# 카테고리 열기

#https://cafe.naver.com/joonggonara?iframe_url=/ArticleSearchList.nhn%3Fsearch.clubid=10050146%26search.searchdate=all%26search.searchBy=0%26search.query=%C5%C3%B9%E8%26search.defaultValue=1%26search.menuid=1723

#https://cafe.naver.com/joonggonara?iframe_url=/ArticleList.nhn%3Fsearch.clubid=10050146%26search.page=237%26search.menuid=1723%26search.boardtype=L

#?iframe_url=/ArticleSearchList.nhn%3Fsearch.clubid=10050146%26search.searchdate=all%26search.searchBy=0%26search.query=%C5%C3%B9%E8%26search.defaultValue=1%26search.menuid=1723

#https://cafe.naver.com/joonggonara?iframe_url=/ArticleSearchList.nhn%3Fsearch.clubid=10050146%26search.searchdate=all%26search.searchBy=0%26search.query=%C5%C3%B9%E8%26search.defaultValue=1%26search.menuid=1723%26search.page=20

#driver.get(f'{url}?iframe_url=/ArticleSearchList.nhn%3Fsearch.clubid=10050146%26search.searchdate=all%26search.searchBy=0%26search.query=%C5%C3%B9%E8%26search.defaultValue=1%26search.menuid=1723%26search.page=20)
         

total_list = []
a_list = []

        
#driver.get("https://cafe.naver.com/joonggonara?iframe_url=/ArticleSearchList.nhn%3Fsearch.clubid=10050146%26search.menuid=1731%26search.searchdate=2020-01-012020-02-20%26search.searchBy=0%26search.sortBy=date%26search.option=3%26userDisplay=50%26search.query=%B0%C5%B7%A1%26search.includeAll=%26search.exclude=%26search.include=%26search.exact=%26search.page=1")
        
#time.sleep(1)
        
#driver.switch_to.frame("cafe_main")# iframe으로 전환

#html = driver.page_source 
#soup = bs(html, 'html.parser')
    
for l in range(0,10000):
    
    pg = str(l+1)
    
    
    addr="https://cafe.naver.com/ArticleSearchList.nhn?search.clubid=10050146&search.menuid=1730&search.searchdate=2021-08-082021-08-15&search.searchBy=026search.query=택배&&search.sortBy=date&search.option=3&userDisplay=50&search.includeAll=&search.exclude=&search.include=&search.exact=&search.page="+pg
    
    #addr = "https://cafe.naver.com/joonggonara?iframe_url=/ArticleSearchList.nhn%3Fsearch.clubid=10050146%26search.menuid=1730%26search.searchdate=2021-08-082021-08-15%26search.searchBy=026search.query=%C5%C3%B9%E8%26%26search.sortBy=date%26search.option=3%26userDisplay=50%26search.includeAll=%26search.exclude=%26search.include=%26search.exact=%26search.page="+pg
    
    driver.get(addr)
    driver.switch_to.frame("cafe_main")
    
    html = driver.page_source 
    soup = bs(html, 'html.parser')
    
    a_title_list = soup.findAll("a",{"class":"article"}) 
    a_regdate_list = soup.findAll("td",{"class":"td_date"})
  

    
    for b, d in zip( a_title_list,a_regdate_list): 
        a_list=[] 
        a_list.append(b.text.strip()) 
        a_list.append(d.text)
        print(a_list)
        total_list.append(a_list)
        
    
    a_title_list = [] 
    a_regdate_list = []

            
   # if l % 10 == 0:
    #    c10 = driver.find_element_by_link_text('다음')
    #    c10.click()
    #else:
    #    a = str(l+1)
    #    c = driver.find_element_by_link_text(a)
    #    c.click()
        
    time.sleep(1)
    
conn.close()
# Out:
# ['[반포동]\n                                \n                                \n\n                                \n                                \n                                    와콤 신티크 16 (DTK 1660) + 스탠드', '21:03']
# ['풍수지리 해바라기 유화 20호 판매, 액자 포함, 화방이나 그림사이트보다 합리적이고 친숙한 가격', '16:04']
# ['[방배동]\n                                \n                                \n\n                                \n                                \n                                    이케아 2인용 쇼파', '15:48']
# ['[서초동]\n                                \n                                \n\n                                \n                                \n                                    에어팟프로 미개봉 초특가 판매!!!', '15:48']
# ['[염곡동]\n                                \n                                \n\n                                \n                                \n                                    도부 N95 마스크', '15:14']
# ['제도 세트', '15:13']
# ['프리미엄 디퓨저7종세트 싸게 드려요', '14:31']
# ...

# %%
col_name = ['content','date']
list_df = pd.DataFrame(total_list, columns=col_name)

list_df.to_csv('/Users/eunyoungshin/Desktop/서초구.csv')
